# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_percentage_error

# %%
data = pd.read_csv('Housing.csv')

# %%
data
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
data.dropna()
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
data['mainroad'] = data['mainroad'].map({'yes':1,'no':0})

# %%
data
# Out:
#         price  area  bedrooms  bathrooms  stories  mainroad guestroom  \
# 0    13300000  7420         4          2        3         1        no
# 1    12250000  8960         4          4        4         1        no
# 2    12250000  9960         3          2        2         1        no
# 3    12215000  7500         4          2        2         1        no
# 4    11410000  7420         4          1        2         1       yes
# ..        ...   ...       ...        ...      ...       ...       ...
# 540   1820000  3000         2          1        1         1        no
# 541   1767150  2400         3          1        1         0        no
# 542   1750000  3620         2          1        1         1        no
# 543   1750000  2910         3          1        1         0        no
# 544   1750000  3850         3          1        2         1        no
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# ...

# %%
data['guestroom'] = data['guestroom'].map({'yes':0.1,'no':0.0})

# %%
data
# Out:
#         price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    13300000  7420         4          2        3         1        0.0
# 1    12250000  8960         4          4        4         1        0.0
# 2    12250000  9960         3          2        2         1        0.0
# 3    12215000  7500         4          2        2         1        0.0
# 4    11410000  7420         4          1        2         1        0.1
# ..        ...   ...       ...        ...      ...       ...        ...
# 540   1820000  3000         2          1        1         1        0.0
# 541   1767150  2400         3          1        1         0        0.0
# 542   1750000  3620         2          1        1         1        0.0
# 543   1750000  2910         3          1        1         0        0.0
# 544   1750000  3850         3          1        2         1        0.0
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# ...

# %%
data['basement'] = data['basement'].map({'no':0,'yes':1})

# %%
data
# Out:
#         price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    13300000  7420         4          2        3         1        0.0
# 1    12250000  8960         4          4        4         1        0.0
# 2    12250000  9960         3          2        2         1        0.0
# 3    12215000  7500         4          2        2         1        0.0
# 4    11410000  7420         4          1        2         1        0.1
# ..        ...   ...       ...        ...      ...       ...        ...
# 540   1820000  3000         2          1        1         1        0.0
# 541   1767150  2400         3          1        1         0        0.0
# 542   1750000  3620         2          1        1         1        0.0
# 543   1750000  2910         3          1        1         0        0.0
# 544   1750000  3850         3          1        2         1        0.0
#
#      basement hotwaterheating airconditioning  parking prefarea  \
# ...

# %%
data['hotwaterheating'] = data['hotwaterheating'].map({'no':0,'yes':1})

# %%
data
# Out:
#         price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    13300000  7420         4          2        3         1        0.0
# 1    12250000  8960         4          4        4         1        0.0
# 2    12250000  9960         3          2        2         1        0.0
# 3    12215000  7500         4          2        2         1        0.0
# 4    11410000  7420         4          1        2         1        0.1
# ..        ...   ...       ...        ...      ...       ...        ...
# 540   1820000  3000         2          1        1         1        0.0
# 541   1767150  2400         3          1        1         0        0.0
# 542   1750000  3620         2          1        1         1        0.0
# 543   1750000  2910         3          1        1         0        0.0
# 544   1750000  3850         3          1        2         1        0.0
#
#      basement  hotwaterheating airconditioning  parking prefarea  \
# ...

# %%
data['airconditioning'] = data['airconditioning'].map({'yes':1,'no':0})
data
# Out:
#         price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    13300000  7420         4          2        3         1        0.0
# 1    12250000  8960         4          4        4         1        0.0
# 2    12250000  9960         3          2        2         1        0.0
# 3    12215000  7500         4          2        2         1        0.0
# 4    11410000  7420         4          1        2         1        0.1
# ..        ...   ...       ...        ...      ...       ...        ...
# 540   1820000  3000         2          1        1         1        0.0
# 541   1767150  2400         3          1        1         0        0.0
# 542   1750000  3620         2          1        1         1        0.0
# 543   1750000  2910         3          1        1         0        0.0
# 544   1750000  3850         3          1        2         1        0.0
#
#      basement  hotwaterheating  airconditioning  parking prefarea  \
# ...

# %%
data['furnishingstatus'].value_counts()
# Out:
# semi-furnished    227
# unfurnished       178
# furnished         140
# Name: furnishingstatus, dtype: int64

# %%
data['furnishingstatus'] = data['furnishingstatus'].map({'unfurnished':0.0,'semi-furnished':0.1,'furnished':0.2})
data
# Out:
#         price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    13300000  7420         4          2        3         1        0.0
# 1    12250000  8960         4          4        4         1        0.0
# 2    12250000  9960         3          2        2         1        0.0
# 3    12215000  7500         4          2        2         1        0.0
# 4    11410000  7420         4          1        2         1        0.1
# ..        ...   ...       ...        ...      ...       ...        ...
# 540   1820000  3000         2          1        1         1        0.0
# 541   1767150  2400         3          1        1         0        0.0
# 542   1750000  3620         2          1        1         1        0.0
# 543   1750000  2910         3          1        1         0        0.0
# 544   1750000  3850         3          1        2         1        0.0
#
#      basement  hotwaterheating  airconditioning  parking prefarea  \
# ...

# %%
data['prefarea'] = data['prefarea'].map({'yes':1,'no':0})

# %%
x = data[['area','bedrooms','bathrooms','stories','parking','mainroad','guestroom','basement','hotwaterheating','airconditioning','prefarea','furnishingstatus']]
y = data[['price']]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
y_pred
# Out:
# array([[5741346.01974646],
#        [4264688.900715  ],
#        [6036963.73387994],
#        [6489773.40513493],
#        [1969744.97812738],
#        [6241235.76428655],
#        [4693506.69014465],
#        [9431141.43322686],
#        [8291604.97702531],
#        [3891320.56107567],
#        [3594001.82741729],
#        [2131231.36091733],
#        [6519959.17252088],
#        [5180693.24772578],
#        [3610194.64703959],
#        [4235278.16792268],
#        [4876931.8829788 ],
#        [5251802.62154795],
#        [3242372.33038174],
#        [3293235.16376032],
#        [3810188.28790741],
#        [6427036.28554292],
#        [3186813.01779633],
#        [3196272.76262034],
#        [7361110.60160709],
#        [6118977.06916584],
#        [5891015.34591746],
#        [4474984.81448728],
#        [5770261.40228341],
#        [5110368.77224498],
#        [8345262.98494144],
#        [3418067.26405981],
#        [2956189.00469944],
#        [2830073.70378957],
# ...

# %%
from sklearn.metrics import mean_squared_error

# %%
mse = mean_absolute_percentage_error(y_test,y_pred)

# %%
mse
# Out:
# 0.16567976793257483

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3)

# %%
dc = DecisionTreeRegressor()

# %%
dc.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred1 = dc.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error

# %%
mse1 = mean_absolute_percentage_error(y_pred1,y_test)

# %%
mse1
# Out:
# 0.23380336232387777

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor()

# %%
rf.fit(x_train, y_train.to_numpy().ravel())
# Out:
# RandomForestRegressor()

# %%
ypred2 = rf.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error

# %%
mse3 = mean_absolute_percentage_error(ypred2,y_test)

# %%
mse3
# Out:
# 0.40943360035586235

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3)

# %%
nv = MultinomialNB()

# %%
nv.fit(x_train,y_train.to_numpy().ravel())
# Out:
# MultinomialNB()

# %%
ypred3 = nv.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error

# %%
mse4 = mean_absolute_percentage_error(y_test,ypred3)

# %%
mse4
# Out:
# 0.3419238726632132

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3)

# %%
from sklearn.naive_bayes import GaussianNB

# %%
gb = GaussianNB()

# %%
gb.fit(x_train,y_train.to_numpy().ravel())
# Out:
# GaussianNB()

# %%
ypred5 =gb.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error

# %%
mse5 = mean_absolute_percentage_error(y_test,ypred5)

# %%
mse5
# Out:
# 0.23490599093385364

# %%
from sklearn.svm import SVC

# %%
svc = SVC()

# %%
svc.fit(x_train,y_train.to_numpy().ravel())
# Out:
# SVC()

# %%
ypred7 = svc.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_percentage_error

# %%
mse6 = mean_absolute_percentage_error(y_test,ypred7)

# %%
mse6
# Out:
# 0.284418316585013

# %%
labels = ['Linear', 'Decision TREE', 'Random', 'NB Multi','NB gaussian','SVC']
values = [mse, mse1, mse3, mse4, mse5, mse6]  # Replace these with your actual values

# Create a bar chart
plt.bar(labels, values, color=['blue', 'orange', 'green', 'red','yellow','pink'])

# Add title and labels
plt.title('Comparison of error values')
plt.xlabel('error values')
plt.ylabel('values')


# Show the plot
plt.show()
